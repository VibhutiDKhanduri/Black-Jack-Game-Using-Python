# %%
suits= ('Hearts','Diamonds','Spades','Clubs')
ranks = ('Two','Three','Four','Five','Six','Seven','Eight','Nine','Ten','Jack','Queen','King','Ace')
values= {'Two': 2,'Three':3,'Four':4,'Five':5,'Six':6,'Seven':7,'Eight':8,'Nine':9,'Ten':10,'Jack':10,
         'Queen':10,'King':10,'Ace':11}

# %%
from IPython.display import clear_output

# %%
class Card:
    def __init__(self,suit,rank):
        self.suit = suit.capitalize()
        self.rank = rank.capitalize()
        self.value = values[rank]
        
    def __str__(self):
        return "It is " +self.rank+" of " + self.suit

# %%
mycard = Card('Hearts','Two')

# %%
mycard.suit
# Out:
# 'Hearts'

# %%
print(mycard)
# Out:
# It is Two of Hearts

# %%
mycard.value
# Out:
# 2

# %%
import random
class Deck:
    
    def __init__(self):
        self.all_cards=[]
    
        for suit in suits:
            for rank in ranks :
            
                self.all_cards.append(Card(suit,rank))
    
    def shuffle(self):
        
        random.shuffle(self.all_cards)
        
    def pull_one_out(self):
        
        return (self.all_cards.pop())

# %%
class Player:
    
    def __init__(self,name,account_balance):
        
        self.name = name
        self.all_cards = []
        self.account_balance = account_balance
        
    def __str__(self):
        
        return self.name +" has ₹" +str(self.account_balance)+" in account"
    
    
    def add_card(self,new_card):
            #a try block to ensure only one card is added at a time
            self.all_cards.append(new_card)
            
    def add_amount(self,amount):
        
        self.account_balance += amount
        
        print(self.__str__())
        
    def deduct_amount(self,amount):
        
        self.account_balance -= amount
        
        print(self.__str__())
    
    def get_cards(self):
        
        return self.all_cards

# %%
class Dealer:
    
    def __init__(self):
        
        self.name = "Dealer"
        self.all_cards = []
        
    def add_card(self,new_card):
        
        self.all_cards.append(new_card)
     
    def get_cards(self):
        
        return self.all_cards

# %%
def gameLogic():
        print("-------------------Welcome to the BlackJack Table at Khanduri Casino--------------------\n\n")
        name = input("Enter your name:  ")
        name = name.title()
        player = Player(name, 3000)
        print(str(player)+"\n")
        play_again =True
        while play_again:
                clear_output( wait= True )       
                choice = ""
                deck = Deck()
                dealer= Dealer()
                sum = 0 #to calculate total value of the cards
                dealer_sum = 0
                count = 0 #to calculate the number of cards given, if count == 2 and sum=21 then blackjack 
                player.all_cards = []
                dealer.all_cards = []
                while True:
                        try:
                            amount = int(input("Enter amount you want to bet ->   "))
                            while(amount<=0 or player.account_balance-amount<0) :
                                print("Enter a valid bet amount")
                                amount = int(input("Enter amount you want to bet ->   "))

                        except:
                                print("Whoops it has to be number")
                                continue
                        else:
                                break

                player.deduct_amount(amount)         
                deck.shuffle()
                player_blackjack = False
                dealer_blackjack = False
                ace_count = 0
                dealer_ace_count = 0

                for num in range(2):
                    player.add_card(deck.pull_one_out())
                    count += 1
                    dealer.add_card(deck.pull_one_out()) 

                print(f'Dealer Card: {dealer.get_cards()[0]}\n')

                print("Your Cards are: ")
                for card in player.get_cards() :
                    print(card,end=" ")
                    sum += card.value
                    if card.value == 11:
                        ace_count +=1
                    if ace_count>0 and sum>21:
                        sum -= 10
                        ace_count = ace_count - 1

                print(sum)
                if(sum == 21 ):
                    print("Congrats mofu its a Black Jack!")
                    player_blackjack= True
                    print(player)
                    
                for card in dealer.get_cards() :
                    dealer_sum += card.value
                    if card.value == 11:
                        dealer_ace_count +=1
                    if dealer_ace_count>0 and dealer_sum>21:
                        dealer_sum -= 10
                        dealer_ace_count = dealer_ace_count - 1


                if(player_blackjack or dealer_blackjack): 
                        print(f'\n\nDealer Card: {dealer.get_cards()[0]}   {dealer.get_cards()[-1]}')
                        print(dealer_sum)
                            #if gets a black jack
                        if(dealer_blackjack):
                            print("Its a push\n")
                            player.add_amount(amount)
                            print(player)
                        elif ((not player_blackjack) and dealer_blackjack):
                                print("Dealer wins\n")
                                print(player)
                        else:
                            print(name+" Wins\n")
                            player.add_amount(2.5*amount)
                            print(player)
                        play_again = input("Wannaaa play again?y/n ").lower()
                        while(choice!='y' and choice!='n'):
                            print("Choice can either be y or n")
                            play_again = input("Wannaaa play again?y/n ").lower()
                        
                        
                        if play_again == 'n':
                            break
                        elif play_again == 'y':
                            continue
                #while( sum < 17) :

                choice = input("Would you like to hit or stay? h/s ?").lower()
                while(choice!='s' and choice!='h'):
                    print("Choice can either be h or s")
                    choice = input("Would you like to hit or stay? h/s ?").lower()
                
                while (choice == 'h' ):
                    player.add_card(deck.pull_one_out())        
                    card = (player.get_cards())[-1]
                    print(card,end=' ')
                    sum += card.value
                    if card.value == 11:
                        ace_count +=1
                    if ace_count>0 and sum>21:
                        sum -= 10
                        ace_count = ace_count - 1
                    print(sum)
                    if(sum>21):  
                        print("Busted! "+name+" loses")
                        print(player)
                        print("\n")
                        break
                    
                    else:   
                        choice = input("Would you like to hit or stay? h/s ?").lower()
                        while(choice!='s' and choice!='h'):
                            print("Choice can either be h or s")
                            choice = input("Would you like to hit or stay? h/s ?").lower()
                
                        if choice == 'h':
                            continue
                        elif choice == 's':
                            break
                
                print(f'\nDealer Cards:\n{dealer.get_cards()[0]} ',end=' ')
                print(dealer.get_cards()[1],end= ' ' )
                print(dealer_sum)
                
                if choice == 's':
                    
                    while(dealer_sum<17):
                        dealer.add_card(deck.pull_one_out())        
                        card = (dealer.get_cards())[-1]
                        print(card,end=' ')
                        dealer_sum += card.value
                        if card.value ==11:
                            dealer_ace_count +=1
                        if dealer_ace_count>0 and dealer_sum>21:
                            dealer_sum -= 10
                            dealer_ace_count = dealer_ace_count - 1
                        print(dealer_sum)
                
                    if(dealer_sum>=17):

                        if(dealer_sum>21):
                            print(name+" Wins!")
                            player.add_amount(2*amount)

                        elif(dealer_sum>sum):
                            print(name+" Loses!")

                        elif(dealer_sum<sum):
                            print(name+" Wins!")
                            player.add_amount(2*amount)

                        elif(dealer_sum==sum):
                            print("Its a push!")
                            player.add_amount(1*amount)



                print("\n"+str(player))


                
                
                play_again = input("\n\n Wanna play again? y/n ").lower()
                while(play_again!='y' and play_again!='n'):
                    print("Choice can either be y or n")
                    play_again = input("\n\n Wanna play again? y/n ").lower()
                
                if play_again == 'n':
                    play_again = False
                elif play_again == 'y':
                    play_again = True


        print("\n ---------------------Thanks for playing-------------------- :) ")

# %%
#Press shift+Enter after selecting this cell to play 
gameLogic()
# Out:
# Enter amount you want to bet ->   500
# Cristiano Ronaldo has ₹2000 in account
# Dealer Card: It is Jack of Hearts
#
# Your Cards are:
# It is Seven of Clubs It is Ace of Hearts 18
# Would you like to hit or stay? h/s ?h
# It is Six of Clubs 14
# Would you like to hit or stay? h/s ?h
# It is Five of Diamonds 19
# Would you like to hit or stay? h/s ?s
#
# Dealer Cards:
# It is Jack of Hearts  It is Four of Diamonds 14
# It is Two of Spades 16
# It is Six of Spades 22
# Cristiano Ronaldo Wins!
# Cristiano Ronaldo has ₹3000 in account
#
# Cristiano Ronaldo has ₹3000 in account
#
#
#  Wanna play again? y/n n
#
#  ---------------------Thanks for playing-------------------- :)
